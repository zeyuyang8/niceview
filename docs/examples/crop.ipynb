# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/home/tom/github/niceview/db/cache/gt-iz-p9-rep2-gis-blend-cell-gene-img.tiff')

# %%
x1, y1, x2, y2 = 4456, 1082, 4481, 1103

# %%
cropped_region = image[y1:y2, x1:x2]
cv2.imwrite('crop.png', cropped_region)
# Out:
# True

# %%
fig, ax = plt.subplots()
ax.imshow(cropped_region)
